# %% [markdown]
# # Smart Billing System — Project Notebook
#
# This notebook demonstrates reading data, billing logic, and sample outputs for the Smart Billing project.

# %%
import pandas as pd
products = pd.read_csv('data/product.csv')
customers = pd.read_csv('data/customer.csv')
products.head()

# %% [markdown]
# **Captured Output (products & customers head):**
#
# ```
# Products (head):
#  ItemID         ItemName  Price  StockQty  TaxRate
#     101     Rice 5kg Bag    300         2     0.05
#     102   Cooking Oil 1L    180        37     0.05
#     103 Wheat Flour 10kg    400        22     0.05
#     104        Soap Pack     60         7     0.05
#     105  Toothpaste 200g     90        24     0.05
#
# Customers (head):
# CustomerID  Name    Type
#       C001 Rahul Regular
#       C002 Priya Premium
#       C003  Amit Regular
#
# ```

# %%
from datetime import datetime
DISCOUNTS = {'Regular': 0.05, 'Premium': 0.10}
# Example simulated billing run (see following markdown for captured output)

# %% [markdown]
# **Captured Output (Simulated Bill):**
#
# ```
# SMART BILLING SYSTEM - Simulated Bill
#
# Customer ID: C001  Type: Regular
# Rice 5kg Bag  x1  @300.00  =  300.00
# Cooking Oil 1L  x1  @180.00  =  180.00
# Wheat Flour 10kg  x1  @400.00  =  400.00
#
# Total before discount: 880.00
# Discount (5%): -44.00
# Taxable Amount: 836.00
# Tax (5.0%): 41.80
# Grand Total: 877.80
#
# ```

# %% [markdown]
# ## Notes
# - This notebook is a non-GUI demonstration of the billing logic.
# - The original GUI app And The Full Code is in `src/billing.py`.
# - The `data/` folder contains the CSV files used as input.
